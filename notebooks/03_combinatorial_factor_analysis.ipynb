# %% [markdown]
# # Combinatorial Factor Analysis
#
# Generated draft notebook for ERP Workflow CWI Lab.

# %%
from pathlib import Path
import pandas as pd

BASE = Path('..')
if not (BASE / 'data').exists():
    BASE = Path('.')

scenarios = pd.read_csv(BASE / 'data/scenarios/scenario_design.csv')
scenarios.head()

# %%
coverage = len(scenarios) / (2 ** 6)
coverage

# %%
scenarios['hamming_weight'].value_counts().sort_index()
