# %% [markdown]
# # ECOUNT-SAP Crosswalk
#
# Generated draft notebook for ERP Workflow CWI Lab.

# %%
from pathlib import Path
import pandas as pd

BASE = Path('..')
if not (BASE / 'data').exists():
    BASE = Path('.')

crosswalk = pd.read_csv(BASE / 'data/mappings/ecount_sap_process_crosswalk.csv')
crosswalk

# %%
crosswalk.groupby(['mapping_level','confidence']).size().reset_index(name='count')
