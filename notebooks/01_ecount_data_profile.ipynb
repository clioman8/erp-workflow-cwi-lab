# %% [markdown]
# # ECOUNT Data Profile
#
# Generated draft notebook for ERP Workflow CWI Lab.

# %%
from pathlib import Path
import pandas as pd

BASE = Path('..')
if not (BASE / 'data').exists():
    BASE = Path('.')

items = pd.read_csv(BASE / 'data/master/items.csv')
warehouses = pd.read_csv(BASE / 'data/master/warehouses.csv')
partners = pd.read_csv(BASE / 'data/master/business_partners.csv')
events = pd.read_csv(BASE / 'data/event_logs/synthetic_integrated_event_log.csv')
items.head(), warehouses.head(), partners.head(), events.head()

# %%
print('items:', len(items))
print('warehouses:', len(warehouses))
print('partners:', len(partners))
print('events:', len(events))
